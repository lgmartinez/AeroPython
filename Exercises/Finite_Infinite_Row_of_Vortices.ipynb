# %% [markdown]
# ## Import Libraries

# %%
import numpy
import math
from matplotlib import pyplot

# %% [markdown]
# ## Define Grid

# %%
N=100

x_start, x_end = -8.0, 8.0
y_start, y_end = -1.0, 1.0

x = numpy.linspace(x_start, x_end, N)
y = numpy.linspace(y_start, y_end, N)

X, Y = numpy.meshgrid(x,y)

# %% [markdown]
# ## Location of vortices

# %%
# This shows the x-location of vortices
n_v = 21

start_vortex, end_vortex = -10, 10

xv_list = numpy.linspace(start_vortex, end_vortex, n_v)

yv_list=numpy.zeros_like(xv_list)

# %% [markdown]
# ## Strength of Vortices

# %%
G = 5.0

gamma = numpy.repeat(G, numpy.size(xv_list))

# %%
index = numpy.arange(0,len(xv_list))

# %% [markdown]
# ## Define functions to calculate velocities and stream function

# %%
def get_velocity_vortices(strength, xv, yv, X, Y):

    u_vortex = + strength/(2*math.pi)*(Y-yv)/((X-xv)**2+(Y-yv)**2)
    v_vortex = - strength/(2*math.pi)*(X-xv)/((X-xv)**2+(Y-yv)**2)
    
    return u_vortex, v_vortex

#def get_streamfunction(strength, xv, yv, X, Y):

   # psi = psi = strength/(4*math.pi)*numpy.log((X-xv)**2+(Y-yv)**2)
    
#    return psi

# %% [markdown]
# ## Calculate velocities and streamfunction

# %%
u_vortices = numpy.zeros((N,N))
v_vortices = numpy.zeros((N,N))


for i in index:
    
    u_v, v_v = get_velocity_vortices(gamma[i], xv_list[i], yv_list[i], X, Y)
    
    u_vortices += u_v
    v_vortices += v_v

# %% [markdown]
# ## Plot

# %%
# plots the streamlines
# %matplotlib inline

size = 20
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, u_vortices, v_vortices, density=2, linewidth=1, arrowsize=1, arrowstyle='->')
pyplot.scatter(xv_list, yv_list, color='r', s=40, marker='o');

# %% [markdown]
# # Infinite Row of Vortices

# %% [markdown]
# ### Calculate the velocity field due to the infinite row of vortices by using mesh points X, Y

# %%
a = (end_vortex-start_vortex)/(n_v-1)

u_vortex = + G/(2*a)*(numpy.sinh((2*(Y)*math.pi)/a))/(numpy.cosh((2*(Y)*math.pi)/a)-numpy.cos((2*(X)*math.pi)/a))
v_vortex = - G/(2*a)*(numpy.sin((2*(X)*math.pi)/a))/(numpy.cosh((2*(Y)*math.pi)/a)-numpy.cos((2*(X)*math.pi)/a))

# %% [markdown]
# ### Plot

# %%
# plots the streamlines
# %matplotlib inline

size = 20
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, u_vortex, v_vortex, density=2, linewidth=1, arrowsize=1, arrowstyle='->')
pyplot.scatter(xv_list, yv_list, color='r', s=40, marker='o');

# %% [markdown]
# ## Conclusion

# %% [raw]
# Comparison on the finite and infinite cases shows that the streamlines become 'more' straight and parallel to the row of vortices and to each other as the number of vortices are increased. This makes sense since as we add more and more vortices to the finite case we are approaching infinity.
